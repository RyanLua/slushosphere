# %% [markdown]
# ## Data Table
# Table with recorded data from the Arduino and sensors. Converts the epoch timestamp to a human-readable date format.

# %%
import pandas

df = pandas.read_csv("../data/DATA.CSV")

df = df.rename(columns={"Timestamp (Epoch)": "Timestamp"})
df["Timestamp"] = pandas.to_datetime(df["Timestamp"], unit="s")
df.head()
# Out:
#             Timestamp  Temperature (°C)  Humidity (%)  Pressure (kPa)  \
# 0 2025-06-21 02:04:25             26.51         44.90          100.83
# 1 2025-06-21 02:04:26             28.35         44.86          100.83
# 2 2025-06-21 02:04:27             28.35         44.90          100.83
# 3 2025-06-21 02:04:28             28.37         44.88          100.83
# 4 2025-06-21 02:04:29             28.39         44.78          100.83
#
#    Illuminance (lx)   Latitude  Longitude  Altitude (m)  Speed (km/h)  \
# 0              3.23  42.316177 -71.334679          51.5          3.94
# 1              4.52  42.316185 -71.334717          45.7          2.48
# 2              3.87  42.316170 -71.334747          45.1          1.51
# 3              3.23  42.316170 -71.334770          44.3          1.64
# 4              2.58  42.316170 -71.334785          44.0          0.58
#
#    Satellites
# 0           4
# 1           4
# 2           4
# 3           4
# 4           4

# %% [markdown]
# ## Sensor Data Graph
# The following plots show the trends for each sensor value over time.

# %%
import matplotlib.pyplot as plt

columns = [
    'Temperature (°C)', 'Humidity (%)', 'Pressure (kPa)',
    'Illuminance (lx)', 'Altitude (m)', 'Speed (km/h)', 'Satellites'
]

fig, axs = plt.subplots(len(columns), 1, figsize=(12, 18), sharex=True)
for i, col in enumerate(columns):
    axs[i].plot(df['Timestamp'], df[col], label=col)
    axs[i].set_ylabel(col)

axs[-1].set_xlabel('Timestamp (readable)')
plt.tight_layout()
plt.show()
